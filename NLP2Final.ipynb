# %%
# Show the files within the current directory
# !ls
# Copy stuff
# !cp sample_data/mnist_test.csv test.csv
# !ls
# Move stuff
# !mv test.csv test_moved.csv
# Remove stuff
# !rm test_moved.csv
# Out:
# sample_data
# sample_data  test.csv

# %%
# You can also run python scripts!
# !python my_script.py --arg1 value1 --arg2 value2

# %% [markdown]
# Cloning the github repo

# %%
# Replace the url with your own
# !git clone https://github.com/matskrone/cw2_2025_2026-students_mmk12
# Out:
# fatal: destination path 'cw2_2025_2026-students_mmk12' already exists and is not an empty directory.

# %%
# Changing directory is a bit trickier as the !cd command does not exactly work
# Use this and replace the path with the path that you want to swap directory
import os
os.chdir("/content/cw2_2025_2026-students_mmk12/part2/")

# %%
ls
# Out:
# model_config.yaml  nmt_model.py     src.model  tgt.vocab          vocab/
# model_large.yaml   predict.py       src.vocab  train_config.yaml  vocab.py
# model_medium.yaml  sanity_check.pt  test.py    train.py           wandb/
# model_small.yaml   sanity_check.py  tgt.model  utils.py

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.7/109.7 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.5 MB/s eta 0:00:00
# ...

# %%
# !python vocab.py
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input_format:
#   model_prefix: vocab/spm
#   model_type: UNIGRAM
#   vocab_size: 15000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
# ...

# %%
# !python sanity_check.py
# Out:
# Number of parameters: 6240 (0.01M)
# All checks passed!

# %%
# !python predict.py \
       --checkpoint-path /content/cw2_2025_2026-students_mmk12/part4/nmt.model \
       --model-config /content/cw2_2025_2026-students_mmk12/part2/model_large.yaml \
       --sentence "Two boys are sitting on a couch that is red and black." \
       --do-sample \
       --top-k 2 \
       --temperature 1
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# load vocab from vocab/vocab.json
# Load model from /content/cw2_2025_2026-students_mmk12/part4/nmt.model
# Number of parameters: 8455296 (8.46M)
# Prediction: Deux garçons sont assis sur un canapé qui est vêtus de rouge et noir.</s>

# %%
#training the small model
# !python train.py \
    --model-config model_small.yaml \
    --train-config train_config.yaml \
    --wandb-project nmt-project2 \
    --wandb-run-name small_run
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Train dataset size: 29000
# Dev dataset size: 1014
# Load vocab from vocab/vocab.json
# uniformly initialize parameters [-0.1, +0.1]
# use device: cuda
# Starting Training!
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %%
# !cp /content/cw2_2025_2026-students_mmk12/part1/models/nmt.model \
    /content/cw2_2025_2026-students_mmk12/part1/model_small.bin

# %%
# !ls -lh /content/cw2_2025_2026-students_mmk12/part1
# Out:
# total 29M
# -rw-r--r--  1 root root  152 Nov 25 19:36 model_config.yaml
# -rw-r--r--  1 root root   70 Nov 25 19:36 model_large.yaml
# -rw-r--r--  1 root root   93 Nov 25 19:36 model_medium.yaml
# drwxr-xr-x  2 root root 4.0K Nov 25 19:52 models
# -rw-r--r--  1 root root  23M Nov 25 22:10 model_small.bin
# -rw-r--r--  1 root root   69 Nov 25 19:36 model_small.yaml
# -rw-r--r--  1 root root  18K Nov 25 19:36 nmt_model.py
# -rw-r--r--  1 root root 3.0K Nov 25 19:36 predict.py
# drwxr-xr-x  2 root root 4.0K Nov 25 19:50 __pycache__
# -rw-r--r--  1 root root 2.4K Nov 25 19:36 sanity_check.pt
# -rw-r--r--  1 root root 2.3K Nov 25 19:36 sanity_check.py
# -rw-r--r--  1 root root 348K Nov 25 19:48 src.model
# -rw-r--r--  1 root root 120K Nov 25 19:48 src.vocab
# -rw-r--r--  1 root root  62K Nov 25 21:19 test_2016_flickr.en
# -rw-r--r--  1 root root  72K Nov 25 21:19 test_2016_flickr.fr
# -rw-r--r--  1 root root 4.7K Nov 25 19:36 test.py
# -rw-r--r--  1 root root 371K Nov 25 19:48 tgt.model
# ...

# %%
#training the medium model
# !python train.py \
    --model-config model_medium.yaml \
    --train-config train_config.yaml \
    --wandb-project nmt-project \
    --wandb-run-name medium_run
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Train dataset size: 29000
# Dev dataset size: 1014
# Load vocab from vocab/vocab.json
# uniformly initialize parameters [-0.1, +0.1]
# use device: cuda
# Starting Training!
# wandb: Currently logged in as: kronebergmats (kronebergmats-heriot-watt-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 1s4ddiox (0.2s)
# wandb: ⣽ setting up run 1s4ddiox (0.2s)
# wandb: ⣾ setting up run 1s4ddiox (0.2s)
# wandb: Tracking run with wandb version 0.23.0
# wandb: Run data is saved locally in /content/cw2_2025_2026-students_mmk12/part1/wandb/run-20251127_180735-1s4ddiox
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run medium_run
# wandb: ⭐️ View project at https://wandb.ai/kronebergmats-heriot-watt-university/nmt-project
# ...

# %%
# !cp /content/cw2_2025_2026-students_mmk12/part1/models/nmt.model \
    /content/cw2_2025_2026-students_mmk12/part1/model_medium.bin

# %%
# !ls -lh /content/cw2_2025_2026-students_mmk12/part1
# Out:
# total 90M
# -rw-r--r--  1 root root  152 Nov 25 19:36 model_config.yaml
# -rw-r--r--  1 root root   70 Nov 25 19:36 model_large.yaml
# -rw-r--r--  1 root root  62M Nov 25 22:31 model_medium.bin
# -rw-r--r--  1 root root   93 Nov 25 19:36 model_medium.yaml
# drwxr-xr-x  2 root root 4.0K Nov 25 19:52 models
# -rw-r--r--  1 root root  23M Nov 25 22:10 model_small.bin
# -rw-r--r--  1 root root   69 Nov 25 19:36 model_small.yaml
# -rw-r--r--  1 root root  18K Nov 25 19:36 nmt_model.py
# -rw-r--r--  1 root root 3.0K Nov 25 19:36 predict.py
# drwxr-xr-x  2 root root 4.0K Nov 25 19:50 __pycache__
# -rw-r--r--  1 root root 2.4K Nov 25 19:36 sanity_check.pt
# -rw-r--r--  1 root root 2.3K Nov 25 19:36 sanity_check.py
# -rw-r--r--  1 root root 348K Nov 25 19:48 src.model
# -rw-r--r--  1 root root 120K Nov 25 19:48 src.vocab
# -rw-r--r--  1 root root  62K Nov 25 21:19 test_2016_flickr.en
# -rw-r--r--  1 root root  72K Nov 25 21:19 test_2016_flickr.fr
# ...

# %%
#training the large model
# !python train.py \
    --model-config model_large.yaml \
    --train-config train_config.yaml \
    --wandb-project nmt-project \
    --wandb-run-name large_run

# %%
# !cp models/nmt.model model_large.bin

# %%
# !ls -lh /content/cw2_2025_2026-students_mmk12/part1
# Out:
# total 275M
# -rw-r--r--  1 root root  152 Nov 25 19:36 model_config.yaml
# -rw-r--r--  1 root root 185M Nov 25 23:29 model_large.bin
# -rw-r--r--  1 root root   70 Nov 25 19:36 model_large.yaml
# -rw-r--r--  1 root root  62M Nov 25 22:31 model_medium.bin
# -rw-r--r--  1 root root   93 Nov 25 19:36 model_medium.yaml
# drwxr-xr-x  2 root root 4.0K Nov 25 19:52 models
# -rw-r--r--  1 root root  23M Nov 25 22:10 model_small.bin
# -rw-r--r--  1 root root   69 Nov 25 19:36 model_small.yaml
# -rw-r--r--  1 root root  18K Nov 25 19:36 nmt_model.py
# -rw-r--r--  1 root root 3.0K Nov 25 19:36 predict.py
# drwxr-xr-x  2 root root 4.0K Nov 25 19:50 __pycache__
# -rw-r--r--  1 root root 2.4K Nov 25 19:36 sanity_check.pt
# -rw-r--r--  1 root root 2.3K Nov 25 19:36 sanity_check.py
# -rw-r--r--  1 root root 348K Nov 25 19:48 src.model
# -rw-r--r--  1 root root 120K Nov 25 19:48 src.vocab
# -rw-r--r--  1 root root  62K Nov 25 21:19 test_2016_flickr.en
# ...

# %%
#computing the BLEU scores(small) here
# !python /content/cw2_2025_2026-students_mmk12/part1/test.py \
    --checkpoint-path /content/cw2_2025_2026-students_mmk12/part1/model_small_1.bin \
    --test-source-file /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.en \
    --test-target-file /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.fr \
    --vocab-file /content/cw2_2025_2026-students_mmk12/part1/vocab/vocab.json \
    --output-file small_output.txt
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Load test source sentences from /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.en
# Load test target sentences from /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.fr
# Load vocab from /content/cw2_2025_2026-students_mmk12/part1/vocab/vocab.json
# Load model from /content/cw2_2025_2026-students_mmk12/part1/model_small_1.bin
# Generating Predictions: 100% 1000/1000 [00:08<00:00, 114.93it/s]
# Corpus BLEU score = 18.94
# Saving predictions to small_output.txt

# %%
# BLEU medium here
# !python /content/cw2_2025_2026-students_mmk12/part1/test.py \
    --checkpoint-path /content/cw2_2025_2026-students_mmk12/part1/model_medium_1.bin \
    --test-source-file /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.en \
    --test-target-file /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.fr \
    --vocab-file /content/cw2_2025_2026-students_mmk12/part1/vocab/vocab.json \
    --output-file medium_output.txt
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Load test source sentences from /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.en
# Load test target sentences from /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.fr
# Load vocab from /content/cw2_2025_2026-students_mmk12/part1/vocab/vocab.json
# Load model from /content/cw2_2025_2026-students_mmk12/part1/model_medium_1.bin
# Generating Predictions: 100% 1000/1000 [00:07<00:00, 127.14it/s]
# Corpus BLEU score = 48.86
# Saving predictions to medium_output.txt

# %%
# BLEU large here
# !python /content/cw2_2025_2026-students_mmk12/part1/test.py \
    --checkpoint-path /content/cw2_2025_2026-students_mmk12/part1/model_large_1.bin \
    --test-source-file /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.en \
    --test-target-file /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.fr \
    --vocab-file /content/cw2_2025_2026-students_mmk12/part1/vocab/vocab.json \
    --output-file large_output.txt
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Load test source sentences from /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.en
# Load test target sentences from /content/cw2_2025_2026-students_mmk12/multi30k_data/test_2016_flickr.fr
# Load vocab from /content/cw2_2025_2026-students_mmk12/part1/vocab/vocab.json
# Load model from /content/cw2_2025_2026-students_mmk12/part1/model_large_1.bin
# Generating Predictions: 100% 1000/1000 [00:08<00:00, 124.70it/s]
# Corpus BLEU score = 53.50
# Saving predictions to large_output.txt

# %%
# !find /content -name "test.en"

# %%
# !cat /content/cw2_2025_2026-students_mmk12/part1/train_config.yaml
# Out:
# train_batch_size: 32
# dev_batch_size: 128
# seed: 0
# max_epoch: 30
# # wait for how many iterations to decay learning rate
# patience: 1
# # learning rate
# lr: 0.001
# # learning rate decay
# lr_decay: 0.5
# # uniformly initialize all parameters
# uniform_init: 0.1
# # perform validation after every 1000 iterations
# valid_niter: 2000
# # Report train loss after every 10 iterations
# log_every: 10
# # Early stopping if no improvement after 5 trials
# max_num_trial: 5

# %%
# !ls -R /content/cw2_2025_2026-students_mmk12/part1
# Out:
# /content/cw2_2025_2026-students_mmk12/part1:
# model_config.yaml  predict.py	    test_2016_flickr.en  train.en  vocab
# model_large.yaml   __pycache__	    test_2016_flickr.fr  train.fr  vocab.py
# model_medium.yaml  sanity_check.pt  test.py		 train.py  wandb
# models		   sanity_check.py  tgt.model		 utils.py
# model_small.yaml   src.model	    tgt.vocab		 val.en
# nmt_model.py	   src.vocab	    train_config.yaml	 val.fr
#
# /content/cw2_2025_2026-students_mmk12/part1/models:
# nmt.model  nmt.model.optim
#
# /content/cw2_2025_2026-students_mmk12/part1/__pycache__:
# nmt_model.cpython-312.pyc  utils.cpython-312.pyc  vocab.cpython-312.pyc
#
# /content/cw2_2025_2026-students_mmk12/part1/vocab:
# vocab.json
#
# /content/cw2_2025_2026-students_mmk12/part1/wandb:
# debug-internal.log	      run-20251125_093315-nl1a5g84
# debug.log		      run-20251125_094847-rhrsyu5j
# latest-run		      run-20251125_195111-ojt7r3jv
# run-20251124_042615-x5fhi882  run-20251125_201057-ytanjt6z
# ...
